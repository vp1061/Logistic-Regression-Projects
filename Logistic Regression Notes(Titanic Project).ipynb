# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('titanic_train.csv')
test = pd.read_csv('titanic_test.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.countplot(x='Survived',hue='Sex',data=train,palette='RdBu_r')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.displot(train['Age'].dropna(),kde=True,bins=30)
# Out:
# C:\Users\VDP\anaconda3\envs\py3-TF2.0\lib\site-packages\seaborn\axisgrid.py:123: UserWarning:
#
# The figure layout has changed to tight

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#train['Fare'].iplot(kind='hist',bins=30)

# %%
#Cleaning
plt.figure(figsize=(10,7))
sns.boxplot(data=train,x='Pclass',y='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
def add_age(col_new_age):
    Age = col_new_age[0]
    Pclass = col_new_age[1]
    
    if pd.isnull(Age):
        if Pclass == 1 :
            return 37
        elif Pclass == 2:
            return 29
        elif Pclass == 3:
            return 24
    else:
        return Age

# %%
train['Age'] = train[['Age','Pclass']].apply(add_age,axis=1)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.heatmap(trainCln.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
#checkpoint before filtering the data of train df and drop cabin
trainCln = train

# %%
trainCln.drop(columns='Cabin',axis=1,inplace=True)

# %%
trainCln.dropna(inplace=True)

# %%
trainCln
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#using dummies converting it to categorical var to 0 or 1
pd.get_dummies(trainCln['Sex'])
# Out:
#      female   male
# 0     False   True
# 1      True  False
# 2      True  False
# 3      True  False
# 4     False   True
# ..      ...    ...
# 886   False   True
# 887    True  False
# 888    True  False
# 889   False   True
# 890   False   True
#
# [889 rows x 2 columns]

# %%
sex = pd.get_dummies(trainCln['Sex'],drop_first=True)

# %%
embark = pd.get_dummies(trainCln['Embarked'],drop_first=True)

# %%
trainCln = pd.concat([trainCln,sex,embark],axis=1)

# %%
trainCln.drop(['Sex','Embarked','Ticket','Name'],axis=1,inplace=True)

# %%
trainCln
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare   male      Q  \
# 0              1         0       3  22.0      1      0   7.2500   True  False
# 1              2         1       1  38.0      1      0  71.2833  False  False
# 2              3         1       3  26.0      0      0   7.9250  False  False
# 3              4         1       1  35.0      1      0  53.1000  False  False
# 4              5         0       3  35.0      0      0   8.0500   True  False
# ..           ...       ...     ...   ...    ...    ...      ...    ...    ...
# 886          887         0       2  27.0      0      0  13.0000   True  False
# 887          888         1       1  19.0      0      0  30.0000  False  False
# 888          889         0       3  24.0      1      2  23.4500  False  False
# 889          890         1       1  26.0      0      0  30.0000   True  False
# 890          891         0       3  32.0      0      0   7.7500   True   True
#
#          S
# 0     True
# ...

# %%
trainCln.drop(['PassengerId'],axis=1,inplace=True)

# %%
trainCln
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare   male      Q      S
# 0           0       3  22.0      1      0   7.2500   True  False   True
# 1           1       1  38.0      1      0  71.2833  False  False  False
# 2           1       3  26.0      0      0   7.9250  False  False   True
# 3           1       1  35.0      1      0  53.1000  False  False   True
# 4           0       3  35.0      0      0   8.0500   True  False   True
# ..        ...     ...   ...    ...    ...      ...    ...    ...    ...
# 886         0       2  27.0      0      0  13.0000   True  False   True
# 887         1       1  19.0      0      0  30.0000  False  False   True
# 888         0       3  24.0      1      2  23.4500  False  False   True
# 889         1       1  26.0      0      0  30.0000   True  False  False
# 890         0       3  32.0      0      0   7.7500   True   True  False
#
# [889 rows x 9 columns]

# %%
#Cleaning
plt.figure(figsize=(10,7))
sns.barplot(data=trainCln,x='Pclass',y='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# **<div style="font-size:30px;color:blue;">ML Logistic Regression</div>**

# %%
#features and train predict
X = trainCln.drop('Survived',axis=1)
y = trainCln['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logModel = LogisticRegression()

# %%
#to train or fit the data(training)
logModel.fit(X_train,y_train)
# Out:
# C:\Users\VDP\anaconda3\envs\py3-TF2.0\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# LogisticRegression()

# %%
#predictions
predictions = logModel.predict(X_test)

# %%
#evaluating the mode mae,mse,rmse
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86       163
#            1       0.82      0.71      0.76       104
#
#     accuracy                           0.83       267
#    macro avg       0.83      0.81      0.81       267
# weighted avg       0.83      0.83      0.83       267
#
# [[147  16]
#  [ 30  74]]
